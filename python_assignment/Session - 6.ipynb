# %%
# 1. Create a Python dictionary called playlist_prices with at least 5 key-value pairs where the key is a Spotify playlist name (as a string) 
# and the value is the playlist's price (as an integer). Print the dictionary.

playlist_prices={"hindi song":2000,"panjabi _song":2100,"gujrati song":1000,"bhojpuri sing":900,"kumar sanu song":3000}

print(playlist_prices)
print(playlist_prices.keys())
print(playlist_prices.values())
# Out:
# {'hindi song': 2000, 'panjabi _song': 2100, 'gujrati song': 1000, 'bhojpuri sing': 900, 'kumar sanu song': 3000}
# dict_keys(['hindi song', 'panjabi _song', 'gujrati song', 'bhojpuri sing', 'kumar sanu song'])
# dict_values([2000, 2100, 1000, 900, 3000])

# %%
# 2. Write a function update_playlist_price(playlist, new_price) that updates the price of a given playlist in the playlist_prices dictionary. 
# it by updating the price of any one playlist and printing the updated dictionary.

playlist_prices={"hindi song":2000,"panjabi _song":2100,"gujrati song":1000,"bhojpuri sing":900,"kumar sanu song":3000}

def update_playlist_price(playlist, new_price):
    playlist_prices[playlist]=new_price

playlist_name=str(input("Enter a pley list name:"))
playlist_new_prices=int(input("Enter a list new price:"))
update_playlist_price(playlist_name,playlist_new_prices)

print(playlist_prices)
# Out:
# {'hindi song': 200, 'panjabi _song': 2100, 'gujrati song': 1000, 'bhojpuri sing': 900, 'kumar sanu song': 3000}

# %%
# 3. Remove a playlist from the playlist_prices dictionary using the del statement. 
# Print the dictionary after deletion to confirm the change.

def delt_playlist(playlist_names):
    del playlist_prices[playlist_names]
    print(playlist_prices)

playlist_name=str(input("Enter a pley list name:"))
delt_playlist(playlist_name)
# Out:
# {'gujrati song': 1000, 'bhojpuri sing': 900, 'kumar sanu song': 3000}

# %%
# 4. Given two sets: set1 contains the names of restaurants you have ordered from on Zomato, and set2 contains the names of restaurants you 
# have ordered from on Swiggy, find and print the union and intersection of these sets.<br><br><em><strong>Hint:</strong> Use the union()
# and intersection() methods of Python sets.</em>
Zomato={"Domino's", "KFC", "Burger King", "Subway"}
Swiggy={"KFC", "Subway", "McDonald's", "Pizza Hut"}

print("union restorent",Zomato.union(Swiggy))
print("intersection restorent ",Zomato.intersection(Swiggy))
# Out:
# union restorent {"McDonald's", 'KFC', 'Subway', 'Pizza Hut', "Domino's", 'Burger King'}
# intersection restorent  {'Subway', 'KFC'}
