# %%
# Create a list called playlist_ids with 5 integers representing Spotify playlist IDs, then use append() to add a new playlist ID at the end 
# and print the updated list.

playlist_ids = [1,2,3,4,5,6]
playlist_ids.append(7)
print(playlist_ids)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
2.
# Simulate a Flipkart shopping cart: start with a list cart_items containing 't-shirt', 'shoes'. 
# Use extend() to add ['jeans', 'cap'] to the cart, then print the final list of items.

cart_items=['t-shirt', 'shoes']
cart_items.extend(['jeans', 'cap'])
print(cart_items)
# Out:
# ['t-shirt', 'shoes', 'jeans', 'cap']

# %%
3.
# Write a function remove_last_item(order_list) that pops the last item from a Zomato order list and returns the removed item.
# Test it with a sample order_list.

order_list=[1,2,3,4,5]

def remove_last_item():
    order_list.pop()
    
print(order_list)
remove_last_item()
print(order_list)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4]

# %%
# Create a tuple called insta_filters with 4 Instagram filter names. Try to update the second filter and observe what error you get.
# Explain in a comment why this happens.<br><br><em><strong>Hint:</strong> Tuples are immutable, so direct assignment won't work.</em>


# Instagram filters
insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")

# This will cause an error
insta_filters[1] = "Gingham"
  
# Error:
# TypeError: 'tuple' object does not support item assignment

# Explanation:
# Tuples are immutable, which means their elements cannot be changed
# after the tuple is created. Therefore, direct assignment to a tuple
# element is not allowed.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 insta_filters = ("Clarendon", "Juno", "Lark", "Valencia")
#       8 # This will cause an error
# ----> 9 insta_filters[1] = "Gingham"
#      11 # Error:
#      12 # TypeError: 'tuple' object does not support item assignment
#      13
#    (...)     16 # after the tuple is created. Therefore, direct assignment to a tuple
#      17 # element is not allowed.
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Given two scenarios — storing a user's favorite genres (which may change) and storing a fixed set of IRCTC train classes 
# ('Sleeper', 'AC 3 Tier', 'AC 2 Tier') — choose whether to use a list or tuple for each. Write one sentence explaining your choice for both.
# User's favorite genres (can change) → Use a List
favorite_genres = ["Action", "Comedy", "Drama"]

# IRCTC train classes (fixed) → Use a Tuple
train_classes = ("Sleeper", "AC 3 Tier", "AC 2 Tier")
print("Favorite Genres:", favorite_genres)
print("Train Classes:", train_classes)
# Out:
# Favorite Genres: ['Action', 'Comedy', 'Drama']
# Train Classes: ('Sleeper', 'AC 3 Tier', 'AC 2 Tier')
