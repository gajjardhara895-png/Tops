# %%
# 1. Write a Python script that checks if a user's entered age is 18 or above and prints 'Eligible for IPL ticket booking' if true,
# otherwise prints 'Not eligible'.


age = int(input("Enter you age :"))

if age > 18:
    print("Eligible for IPL ticket booking")
else:
    print("Not eligible")
# Out:
# Eligible for IPL ticket booking

# %%
# 2. Create a Python program that takes the number of followers as input and uses if, elif, and else to print 'Micro Influencer'
# if followers < 10,000,'Rising Star' if between 10,000 and 100,000, and 'Celebrity' if above 100,000.


name=str(input("Enter your user name: "))
followers=int(input("Enter your followers "))

if followers < 10000:
    print(f"{name} is a Micro Influencer")
elif followers > 10000 and followers <100000:
    print(f"{name} is a Rising Star")
else :
    print(f" {name} is a Celebrity ")
# Out:
#  Dhara is a Celebrity

# %%
# 3. Build a Python script that asks the user for their Zomato order total and prints 
# 'Apply Free Delivery' if total is above 299, 'Add more items 
# for free delivery' if between 200 and 299, else 'Delivery charges apply'.


Zomato_order_total=int(input("Enter your Zomato order total:"))

if Zomato_order_total >299:
    print("Apply Free Delivery")
elif Zomato_order_total >=200 and Zomato_order_total <=299:
    print("Add more items for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Add more items for free delivery

# %%
# 4. Write a Python program using nested if statements: take a user's entered Flipkart cart value and payment method ('UPI', 'Card', 'Cash').
# If the cart value is above 1000 and payment method is 'UPI', print 'Eligible for 10% cashback'; if above 1000 and payment is not 'UPI',
# print 'Eligible for 5% cashback'; else print 'No cashback'.

value = int(input("Enter Flipkart cart value: "))
payment_method = input("Enter payment method (UPI/Card/Cash): ").upper()

if value > 1000 and payment_method=="UPI":
    if payment_method == "UPI":
        print("Eligible for 10% cashback.  your final amount is: ", value - value*10/100 )
elif value >1000:
    print("Eligible for 5% cashback", value - value*5/100)
else:
    print("No cashback")
# Out:
# Eligible for 10% cashback.  your final amount is:  4500.0
