# %%
#1.Create a DataFrame named 'movies' with columns: 'title', 'rating', and 'release_year' for at least 6 popular Bollywood films. Use sort_values() to display the movies sorted by 'rating' from highest to lowest.

import pandas as pd

movies = pd.DataFrame({
    "title": [
        "Dangal",
        "3 Idiots",
        "Taare Zameen Par",
        "Sholay",
        "Lagaan",
        "12th Fail"
    ],
    "rating": [8.3, 8.4, 8.3, 8.1, 8.1, 8.7],
    "release_year": [2016, 2009, 2007, 1975, 2001, 2023]
})

result = movies.sort_values("rating", ascending=False)

print(result)
# Out:
#               title  rating  release_year
# 5         12th Fail     8.7          2023
# 1          3 Idiots     8.4          2009
# 0            Dangal     8.3          2016
# 2  Taare Zameen Par     8.3          2007
# 3            Sholay     8.1          1975
# 4            Lagaan     8.1          2001

# %%
# 2.Given a DataFrame of IPL teams with columns 'team', 'points', and 'net_run_rate', use sort_index() to sort the DataFrame by the default index in descending order, then print the result.
import pandas as pd

ipl = pd.DataFrame({
    "team": ["CSK", "MI", "RCB", "KKR", "GT"],
    "points": [17, 16, 15, 14, 13],
    "net_run_rate": [0.65, 0.42, 0.31, 0.28, 0.15]
})

result = ipl.sort_index(ascending=False)

print(result)
# Out:
#   team  points  net_run_rate
# 4   GT      13          0.15
# 3  KKR      14          0.28
# 2  RCB      15          0.31
# 1   MI      16          0.42
# 0  CSK      17          0.65

# %%
#3. Reset the index of a DataFrame containing a list of trending YouTube videos (columns: 'video_title', 'views', 'likes'), and make sure the old index is not added as a column in the result.
import pandas as pd

youtube = pd.DataFrame({
    "video_title": [
        "Music Video",
        "Comedy Video",
        "Gaming Video",
        "Travel Vlog"
    ],
    "views": [5000000, 3500000, 2500000, 1800000],
    "likes": [400000, 300000, 200000, 150000]
}, index=[10, 20, 30, 40])

print("Before Reset:")
print(youtube)

result = youtube.reset_index(drop=True)

print("\nAfter Reset:")
print(result)
# Out:
# Before Reset:
#      video_title    views   likes
# 10   Music Video  5000000  400000
# 20  Comedy Video  3500000  300000
# 30  Gaming Video  2500000  200000
# 40   Travel Vlog  1800000  150000
#
# After Reset:
#     video_title    views   likes
# 0   Music Video  5000000  400000
# 1  Comedy Video  3500000  300000
# 2  Gaming Video  2500000  200000
# 3   Travel Vlog  1800000  150000

# %%
#4.You have a DataFrame of Zomato restaurant names and their ratings. Use reindex() to rearrange the rows so that your favorite restaurant appears first, followed by the rest in any order.

import pandas as pd

zomato = pd.DataFrame({
    "restaurant": [
        "Dominos",
        "Pizza Hut",
        "McDonald's",
        "Subway"
    ],
    "rating": [4.2, 4.5, 4.1, 4.0]
})

print("Original DataFrame:")
print(zomato)

result = zomato.reindex([1, 0, 2, 3])

print("\nAfter Reindex:")
print(result)
# Out:
# Original DataFrame:
#    restaurant  rating
# 0     Dominos     4.2
# 1   Pizza Hut     4.5
# 2  McDonald's     4.1
# 3      Subway     4.0
#
# After Reindex:
#    restaurant  rating
# 1   Pizza Hut     4.5
# 0     Dominos     4.2
# 2  McDonald's     4.1
# 3      Subway     4.0

# %%
#5. Take a DataFrame of Flipkart products with columns 'product_name', 'price', and 'discount'. First, sort the products by 'discount' descending, then reset the index so it starts from 0 and is sequential after sorting.
import pandas as pd

flipkart = pd.DataFrame({
    "product_name": [
        "Laptop",
        "Mobile",
        "Headphones",
        "Smartwatch",
        "Keyboard"
    ],
    "price": [50000, 20000, 3000, 5000, 1500],
    "discount": [20, 30, 15, 40, 25]
})

result = flipkart.sort_values(
    "discount",
    ascending=False
).reset_index(drop=True)

print(result)
# Out:
#   product_name  price  discount
# 0   Smartwatch   5000        40
# 1       Mobile  20000        30
# 2     Keyboard   1500        25
# 3       Laptop  50000        20
# 4   Headphones   3000        15
