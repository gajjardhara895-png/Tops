# %%
# 1. Read IPL match results CSV and display first 10 rows

import pandas as pd

ipl = pd.read_csv("ipl_matches.csv")

print(ipl.head(10))
# Out:
# My Scores: [4 5 3 4 2]

# %%
#2. Mobile Expenses Excel — read_excel() + tail(3)
# Load Excel file
import pandas as pd

expenses = pd.read_excel("mobile_expenses.xlsx")

# Display last 3 rows
print("\nLast 3 Rows:")
print(expenses.tail(3))
# Out:
# Last 3 Rows:
#          Date  Calegory  Amount
# 3  15-01-2026  Recharge     299
# 4  20-01-2026  Internet     499
# 5  25-01-2026     Calls     199

# %%
#3. Food Delivery / Zomato Dataset — info() + describe()
# Load Zomato dataset
zomato = pd.read_csv("zomato.csv")

# Dataset information
print("\nDataset Information:")
zomato.info()

# Statistical summary
print("\nStatistical Summary:")
print(zomato.describe(include="all"))
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order         17 non-null     int64
#  1   Order Date    17 non-null     str
#  2   Quarter       17 non-null     str
#  3   Day           17 non-null     str
#  4   Dish Name     17 non-null     str
#  5   Food Type     17 non-null     str
#  6   Price (INR)   17 non-null     float64
#  7   Rating        17 non-null     float64
#  8   Rating Count  17 non-null     int64
# dtypes: float64(2), int64(2), str(5)
# memory usage: 1.8 KB
#
# Statistical Summary:
#             order Order Date Quarter  Day             Dish Name Food Type  \
# count   17.000000         17      17   17                    17        17
# unique        NaN         17       3    7                    17         1
# top           NaN  6/29/2025      Q2  Sun  Butter Murukku-200gm       Veg
# ...

# %%
#4. First 20 rows to filtered_data.csv export
# Select first 20 rows
import pandas as pd

# Load IPL dataset first
ipl = pd.read_csv("ipl_matches.csv")

# Select first 20 rows
filtered_data = ipl.head(20)

# Export to CSV
filtered_data.to_csv("filtered_data.csv", index=False)

print("First 20 rows exported successfully!")
# Out:
# First 20 rows exported successfully!

# %%
# 5. Export Dataset to Excel

ipl.to_excel(
    "ipl_analysis.xlsx",
    sheet_name="Analysis2024",
    index=False
)

print("\nIPL dataset exported to ipl_analysis.xlsx")
print("Sheet Name: Analysis2024")
# Out:
# IPL dataset exported to ipl_analysis.xlsx
# Sheet Name: Analysis2024
