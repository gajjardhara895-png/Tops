# %%
#1.Create a Pandas DataFrame with a column 'username' containing 5 Instagram usernames in mixed case (e.g., 'CoolDude', 'foodieQueen', etc.), then use str.lower to convert all usernames to lowercase and print the result.
import pandas as pd

instagram = pd.DataFrame({
    "username": [
        "CoolDude",
        "foodieQueen",
        "TRAVELGirl",
        "FashionStar",
        "TechLover"
    ]
})

# Convert usernames to lowercase
instagram["username"] = instagram["username"].str.lower()

print(instagram)
# Out:
#       username
# 0     cooldude
# 1  foodiequeen
# 2   travelgirl
# 3  fashionstar
# 4    techlover

# %%
#2.Given a Pandas Series of song titles from your Spotify playlist, use str.replace to remove all occurrences of the word 'Remix' from the titles and display the cleaned list.
import pandas as pd

songs = pd.Series([
    "Shape of You Remix",
    "Perfect",
    "Believer Remix",
    "Senorita",
    "Faded Remix"
])

# Remove the word Remix
cleaned_songs = songs.str.replace("Remix", "", regex=False)

print(cleaned_songs)
# Out:
# 0    Shape of You
# 1          Perfect
# 2        Believer
# 3         Senorita
# 4           Faded
# dtype: str

# %%
#3.You have a DataFrame with a 'review' column containing user reviews from Zomato. Use str.contains to filter and display only the reviews that mention the word 'delivery'.<br><br><em><strong>Hint:</strong> Remember to handle case sensitivity so that 'Delivery' and 'delivery' are both matched.</em>
import pandas as pd

reviews = pd.DataFrame({
    "review": [
        "Food was good and delivery was fast",
        "Amazing taste",
        "Delivery was late",
        "Excellent restaurant",
        "The food delivery was excellent"
    ]
})

# Find reviews containing delivery
result = reviews[reviews["review"].str.contains("delivery", case=False, na=False)]

print(result)
# Out:
#                                 review
# 0  Food was good and delivery was fast
# 2                    Delivery was late
# 4      The food delivery was excellent

# %%
#4.Take a Pandas Series of Flipkart product categories in the format 'Electronics/Mobiles/Smartphones', 'Home/Kitchen/Appliances', etc. Use str.split to extract just the main category (the part before the first '/') and create a new column with these values.
import pandas as pd

products = pd.DataFrame({
    "Category": [
        "Electronics/Mobiles/Smartphones",
        "Home/Kitchen/Appliances",
        "Fashion/Men/Shirts",
        "Beauty/Makeup/Lipstick",
        "Grocery/Food/Snacks"
    ]
})

# Extract main category
products["MainCategory"] = products["Category"].str.split("/").str[0]

print(products)
# Out:
#                           Category MainCategory
# 0  Electronics/Mobiles/Smartphones  Electronics
# 1          Home/Kitchen/Appliances         Home
# 2               Fashion/Men/Shirts      Fashion
# 3           Beauty/Makeup/Lipstick       Beauty
# 4              Grocery/Food/Snacks      Grocery

# %%
#5.Given a DataFrame of YouTube video titles, use str.upper to convert all titles to uppercase, then chain str.replace to substitute every space with an underscore.<br><br><em><strong>Constraint:</strong> Do this in a single line of code for the transformation.</em>

import pandas as pd

youtube = pd.DataFrame({
    "Title": [
        "How to Learn Python",
        "Power BI Tutorial",
        "Pandas for Beginners",
        "Excel Data Analysis"
    ]
})

# One-line transformation
youtube["Title"] = youtube["Title"].str.upper().str.replace(" ", "_", regex=False)

print(youtube)
# Out:
#                   Title
# 0   HOW_TO_LEARN_PYTHON
# 1     POWER_BI_TUTORIAL
# 2  PANDAS_FOR_BEGINNERS
# 3   EXCEL_DATA_ANALYSIS
